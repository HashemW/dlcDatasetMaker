# %%
import os
import sys
import shutil
from pathlib import Path

def merge_test_folder(dataset_base_path: str, test_folder_name: str):
    """
    Merges a temporary test folder into the main dataset, renaming files sequentially
    for 1-indexed file systems.
    """
    base_path = Path(dataset_base_path)
    if not base_path.is_dir():
        print(f"Error: Dataset base path '{base_path}' does not exist.")
        return

    print(f"Starting merge process for test folder: '{test_folder_name}'")
    print("-" * 50)

    for set_type in ['train', 'valid']:
        print(f"\nProcessing '{set_type}' set...")

        dest_img_dir = base_path / set_type / 'images'
        dest_lbl_dir = base_path / set_type / 'labels'
        src_img_dir = dest_img_dir / test_folder_name
        src_lbl_dir = dest_lbl_dir / test_folder_name

        if not src_img_dir.is_dir():
            print(f"Source image folder not found, skipping: {src_img_dir}")
            continue
        if not src_lbl_dir.is_dir():
            print(f"Source label folder not found, skipping: {src_lbl_dir}")
            continue

        start_index = len(list(dest_img_dir.glob('*.jpg')))
        print(f"'{dest_img_dir.name}' contains {start_index} images. New files will start from index {start_index + 1}.")

        source_images = sorted(list(src_img_dir.glob('*.jpg')))
        
        if not source_images:
            print("No images found in the source directory.")

        for i, src_img_path in enumerate(source_images):
            src_lbl_path = src_lbl_dir / f"{src_img_path.stem}.txt"
            
            if not src_lbl_path.exists():
                print(f"  Warning: Label file not found for {src_img_path.name}. Skipping this image.")
                continue

            # ## FIX: Add 1 to correctly handle 1-indexed file naming
            new_index = start_index + i + 1
            new_name_base = f"{new_index:06d}"
            
            dest_img_path = dest_img_dir / f"{new_name_base}.jpg"
            dest_lbl_path = dest_lbl_dir / f"{new_name_base}.txt"
            
            print(f"  Moving {src_img_path.name} -> {dest_img_path.name}")
            shutil.move(src_img_path, dest_img_path)
            shutil.move(src_lbl_path, dest_lbl_path)

        try:
            if not any(src_img_dir.iterdir()):
                print(f"Cleaning up empty source folder: {src_img_dir}")
                src_img_dir.rmdir()
            if not any(src_lbl_dir.iterdir()):
                print(f"Cleaning up empty source folder: {src_lbl_dir}")
                src_lbl_dir.rmdir()
        except OSError as e:
            print(f"Error removing source directory: {e}. It might not be empty.")

    print("\n" + "-" * 50)
    print("Merge process completed successfully.")

# %%
dataset_path = "/fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset"
folder_name = "arabeql1"

# --- SAFETY CHECK ---
# It's always a good idea to have a confirmation before modifying the file system.
print(f"\nThis script will move and rename files from:")
print(f"  - {Path(dataset_path) / 'train/images' / folder_name}")
print(f"  - {Path(dataset_path) / 'train/labels' / folder_name}")
print(f"  - {Path(dataset_path) / 'valid/images' / folder_name}")
print(f"  - {Path(dataset_path) / 'valid/labels' / folder_name}")
print(f"\nInto the parent directories and will remove the source folders if empty.")

# confirmation = input("Are you sure you want to proceed? (y/n): ")
# if confirmation.lower() != 'y':
#     print("Operation cancelled.")
#     sys.exit(0)

merge_test_folder(dataset_path, folder_name)
# Out:
# This script will move and rename files from:
#   - /fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset/train/images/abeq2
#   - /fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset/train/labels/abeq2
#   - /fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset/valid/images/abeq2
#   - /fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset/valid/labels/abeq2
#
# Into the parent directories and will remove the source folders if empty.
# Starting merge process for test folder: 'abeq2'
# --------------------------------------------------
#
# Processing 'train' set...
# 'images' contains 264 images. New files will start from index 265.
#   Moving 000001.jpg -> 000265.jpg
#   Moving 000002.jpg -> 000266.jpg
#   Moving 000003.jpg -> 000267.jpg
#   Moving 000004.jpg -> 000268.jpg
#   Moving 000005.jpg -> 000269.jpg
#   Moving 000006.jpg -> 000270.jpg
#   Moving 000007.jpg -> 000271.jpg
#   Moving 000008.jpg -> 000272.jpg
#   Moving 000009.jpg -> 000273.jpg
#   Moving 000010.jpg -> 000274.jpg
#   Moving 000011.jpg -> 000275.jpg
#   Moving 000012.jpg -> 000276.jpg
#   Moving 000013.jpg -> 000277.jpg
#   Moving 000014.jpg -> 000278.jpg
#   Moving 000015.jpg -> 000279.jpg
#   Moving 000016.jpg -> 000280.jpg
#   Moving 000017.jpg -> 000281.jpg
#   Moving 000018.jpg -> 000282.jpg
#   Moving 000019.jpg -> 000283.jpg
#   Moving 000020.jpg -> 000284.jpg
#   Moving 000021.jpg -> 000285.jpg
#   Moving 000022.jpg -> 000286.jpg
#   Moving 000023.jpg -> 000287.jpg
#   Moving 000024.jpg -> 000288.jpg
#   Moving 000025.jpg -> 000289.jpg
#   Moving 000026.jpg -> 000290.jpg
#   Moving 000027.jpg -> 000291.jpg
#   Moving 000028.jpg -> 000292.jpg
#   Moving 000029.jpg -> 000293.jpg
#   Moving 000030.jpg -> 000294.jpg
#   Moving 000031.jpg -> 000295.jpg
#   Moving 000032.jpg -> 000296.jpg
#   Moving 000033.jpg -> 000297.jpg
#   Moving 000034.jpg -> 000298.jpg
#   Moving 000035.jpg -> 000299.jpg
#   Moving 000036.jpg -> 000300.jpg
#   Moving 000037.jpg -> 000301.jpg
#   Moving 000038.jpg -> 000302.jpg
#   Moving 000039.jpg -> 000303.jpg
#   Moving 000040.jpg -> 000304.jpg
#   Moving 000041.jpg -> 000305.jpg
#   Moving 000042.jpg -> 000306.jpg
#   Moving 000043.jpg -> 000307.jpg
#   Moving 000044.jpg -> 000308.jpg
#   Moving 000045.jpg -> 000309.jpg
#   Moving 000046.jpg -> 000310.jpg
#   Moving 000047.jpg -> 000311.jpg
#   Moving 000048.jpg -> 000312.jpg
#   Moving 000049.jpg -> 000313.jpg
#   Moving 000050.jpg -> 000314.jpg
#   Moving 000051.jpg -> 000315.jpg
#   Moving 000052.jpg -> 000316.jpg
#   Moving 000053.jpg -> 000317.jpg
#   Moving 000054.jpg -> 000318.jpg
#   Moving 000055.jpg -> 000319.jpg
#   Moving 000056.jpg -> 000320.jpg
#   Moving 000057.jpg -> 000321.jpg
#   Moving 000058.jpg -> 000322.jpg
#   Moving 000059.jpg -> 000323.jpg
#   Moving 000060.jpg -> 000324.jpg
#   Moving 000061.jpg -> 000325.jpg
#   Moving 000062.jpg -> 000326.jpg
#   Moving 000063.jpg -> 000327.jpg
#   Moving 000064.jpg -> 000328.jpg
#   Moving 000065.jpg -> 000329.jpg
#   Moving 000066.jpg -> 000330.jpg
#   Moving 000067.jpg -> 000331.jpg
#   Moving 000068.jpg -> 000332.jpg
#   Moving 000069.jpg -> 000333.jpg
#   Moving 000070.jpg -> 000334.jpg
#   Moving 000071.jpg -> 000335.jpg
#   Moving 000072.jpg -> 000336.jpg
#   Moving 000073.jpg -> 000337.jpg
#   Moving 000074.jpg -> 000338.jpg
#   Moving 000075.jpg -> 000339.jpg
#   Moving 000076.jpg -> 000340.jpg
#   Moving 000077.jpg -> 000341.jpg
#   Moving 000078.jpg -> 000342.jpg
#   Moving 000079.jpg -> 000343.jpg
#   Moving 000080.jpg -> 000344.jpg
#   Moving 000081.jpg -> 000345.jpg
#   Moving 000082.jpg -> 000346.jpg
#   Moving 000083.jpg -> 000347.jpg
#   Moving 000084.jpg -> 000348.jpg
#   Moving 000085.jpg -> 000349.jpg
#   Moving 000086.jpg -> 000350.jpg
#   Moving 000087.jpg -> 000351.jpg
#   Moving 000088.jpg -> 000352.jpg
#   Moving 000089.jpg -> 000353.jpg
#   Moving 000090.jpg -> 000354.jpg
#   Moving 000091.jpg -> 000355.jpg
#   Moving 000092.jpg -> 000356.jpg
#   Moving 000093.jpg -> 000357.jpg
#   Moving 000094.jpg -> 000358.jpg
#   Moving 000095.jpg -> 000359.jpg
#   Moving 000096.jpg -> 000360.jpg
#   Moving 000097.jpg -> 000361.jpg
#   Moving 000098.jpg -> 000362.jpg
#   Moving 000099.jpg -> 000363.jpg
#   Moving 000100.jpg -> 000364.jpg
#   Moving 000101.jpg -> 000365.jpg
#   Moving 000102.jpg -> 000366.jpg
#   Moving 000103.jpg -> 000367.jpg
#   Moving 000104.jpg -> 000368.jpg
#   Moving 000105.jpg -> 000369.jpg
#   Moving 000106.jpg -> 000370.jpg
#   Moving 000107.jpg -> 000371.jpg
#   Moving 000108.jpg -> 000372.jpg
#   Moving 000109.jpg -> 000373.jpg
#   Moving 000110.jpg -> 000374.jpg
#   Moving 000111.jpg -> 000375.jpg
#   Moving 000112.jpg -> 000376.jpg
#   Moving 000113.jpg -> 000377.jpg
#   Moving 000114.jpg -> 000378.jpg
#   Moving 000115.jpg -> 000379.jpg
#   Moving 000116.jpg -> 000380.jpg
#   Moving 000117.jpg -> 000381.jpg
#   Moving 000118.jpg -> 000382.jpg
#   Moving 000119.jpg -> 000383.jpg
#   Moving 000120.jpg -> 000384.jpg
#   Moving 000121.jpg -> 000385.jpg
#   Moving 000122.jpg -> 000386.jpg
#   Moving 000123.jpg -> 000387.jpg
#   Moving 000124.jpg -> 000388.jpg
#   Moving 000125.jpg -> 000389.jpg
#   Moving 000126.jpg -> 000390.jpg
#   Moving 000127.jpg -> 000391.jpg
#   Moving 000128.jpg -> 000392.jpg
#   Moving 000129.jpg -> 000393.jpg
#   Moving 000130.jpg -> 000394.jpg
#   Moving 000131.jpg -> 000395.jpg
#   Moving 000132.jpg -> 000396.jpg
#   Moving 000133.jpg -> 000397.jpg
#   Moving 000134.jpg -> 000398.jpg
#   Moving 000135.jpg -> 000399.jpg
#   Moving 000136.jpg -> 000400.jpg
#   Moving 000137.jpg -> 000401.jpg
#   Moving 000138.jpg -> 000402.jpg
#   Moving 000139.jpg -> 000403.jpg
#   Moving 000140.jpg -> 000404.jpg
#   Moving 000141.jpg -> 000405.jpg
#   Moving 000142.jpg -> 000406.jpg
#   Moving 000143.jpg -> 000407.jpg
#   Moving 000144.jpg -> 000408.jpg
#   Moving 000145.jpg -> 000409.jpg
#   Moving 000146.jpg -> 000410.jpg
#   Moving 000147.jpg -> 000411.jpg
#   Moving 000148.jpg -> 000412.jpg
#   Moving 000149.jpg -> 000413.jpg
#   Moving 000150.jpg -> 000414.jpg
#   Moving 000151.jpg -> 000415.jpg
#   Moving 000152.jpg -> 000416.jpg
#   Moving 000153.jpg -> 000417.jpg
#   Moving 000154.jpg -> 000418.jpg
#   Moving 000155.jpg -> 000419.jpg
#   Moving 000156.jpg -> 000420.jpg
#   Moving 000157.jpg -> 000421.jpg
#   Moving 000158.jpg -> 000422.jpg
#   Moving 000159.jpg -> 000423.jpg
#   Moving 000160.jpg -> 000424.jpg
#   Moving 000161.jpg -> 000425.jpg
#   Moving 000162.jpg -> 000426.jpg
#   Moving 000163.jpg -> 000427.jpg
#   Moving 000164.jpg -> 000428.jpg
#   Moving 000165.jpg -> 000429.jpg
#   Moving 000166.jpg -> 000430.jpg
#   Moving 000167.jpg -> 000431.jpg
#   Moving 000168.jpg -> 000432.jpg
#   Moving 000169.jpg -> 000433.jpg
#   Moving 000170.jpg -> 000434.jpg
#   Moving 000171.jpg -> 000435.jpg
#   Moving 000172.jpg -> 000436.jpg
#   Moving 000173.jpg -> 000437.jpg
#   Moving 000174.jpg -> 000438.jpg
#   Moving 000175.jpg -> 000439.jpg
#   Moving 000176.jpg -> 000440.jpg
#   Moving 000177.jpg -> 000441.jpg
#   Moving 000178.jpg -> 000442.jpg
#   Moving 000179.jpg -> 000443.jpg
#   Moving 000180.jpg -> 000444.jpg
#   Moving 000181.jpg -> 000445.jpg
#   Moving 000182.jpg -> 000446.jpg
#   Moving 000183.jpg -> 000447.jpg
#   Moving 000184.jpg -> 000448.jpg
#   Moving 000185.jpg -> 000449.jpg
#   Moving 000186.jpg -> 000450.jpg
#   Moving 000187.jpg -> 000451.jpg
#   Moving 000188.jpg -> 000452.jpg
#   Moving 000189.jpg -> 000453.jpg
#   Moving 000190.jpg -> 000454.jpg
#   Moving 000191.jpg -> 000455.jpg
#   Moving 000192.jpg -> 000456.jpg
#   Moving 000193.jpg -> 000457.jpg
#   Moving 000194.jpg -> 000458.jpg
#   Moving 000195.jpg -> 000459.jpg
#   Moving 000196.jpg -> 000460.jpg
#   Moving 000197.jpg -> 000461.jpg
#   Moving 000198.jpg -> 000462.jpg
#   Moving 000199.jpg -> 000463.jpg
#   Moving 000200.jpg -> 000464.jpg
#   Moving 000201.jpg -> 000465.jpg
#   Moving 000202.jpg -> 000466.jpg
#   Moving 000203.jpg -> 000467.jpg
#   Moving 000204.jpg -> 000468.jpg
#   Moving 000205.jpg -> 000469.jpg
#   Moving 000206.jpg -> 000470.jpg
#   Moving 000207.jpg -> 000471.jpg
#   Moving 000208.jpg -> 000472.jpg
#   Moving 000209.jpg -> 000473.jpg
#   Moving 000210.jpg -> 000474.jpg
#   Moving 000211.jpg -> 000475.jpg
#   Moving 000212.jpg -> 000476.jpg
#   Moving 000213.jpg -> 000477.jpg
#   Moving 000214.jpg -> 000478.jpg
#   Moving 000215.jpg -> 000479.jpg
#   Moving 000216.jpg -> 000480.jpg
#   Moving 000217.jpg -> 000481.jpg
#   Moving 000218.jpg -> 000482.jpg
#   Moving 000219.jpg -> 000483.jpg
#   Moving 000220.jpg -> 000484.jpg
#   Moving 000221.jpg -> 000485.jpg
#   Moving 000222.jpg -> 000486.jpg
#   Moving 000223.jpg -> 000487.jpg
#   Moving 000224.jpg -> 000488.jpg
#   Moving 000225.jpg -> 000489.jpg
#   Moving 000226.jpg -> 000490.jpg
#   Moving 000227.jpg -> 000491.jpg
#   Moving 000228.jpg -> 000492.jpg
#   Moving 000229.jpg -> 000493.jpg
#   Moving 000230.jpg -> 000494.jpg
#   Moving 000231.jpg -> 000495.jpg
#   Moving 000232.jpg -> 000496.jpg
#   Moving 000233.jpg -> 000497.jpg
#   Moving 000234.jpg -> 000498.jpg
#   Moving 000235.jpg -> 000499.jpg
#   Moving 000236.jpg -> 000500.jpg
#   Moving 000237.jpg -> 000501.jpg
#   Moving 000238.jpg -> 000502.jpg
#   Moving 000239.jpg -> 000503.jpg
#   Moving 000240.jpg -> 000504.jpg
#   Moving 000241.jpg -> 000505.jpg
#   Moving 000242.jpg -> 000506.jpg
#   Moving 000243.jpg -> 000507.jpg
#   Moving 000244.jpg -> 000508.jpg
#   Moving 000245.jpg -> 000509.jpg
#   Moving 000246.jpg -> 000510.jpg
#   Moving 000247.jpg -> 000511.jpg
#   Moving 000248.jpg -> 000512.jpg
#   Moving 000249.jpg -> 000513.jpg
#   Moving 000250.jpg -> 000514.jpg
#   Moving 000251.jpg -> 000515.jpg
#   Moving 000252.jpg -> 000516.jpg
#   Moving 000253.jpg -> 000517.jpg
#   Moving 000254.jpg -> 000518.jpg
#   Moving 000255.jpg -> 000519.jpg
#   Moving 000256.jpg -> 000520.jpg
#   Moving 000257.jpg -> 000521.jpg
#   Moving 000258.jpg -> 000522.jpg
#   Moving 000259.jpg -> 000523.jpg
#   Moving 000260.jpg -> 000524.jpg
#   Moving 000261.jpg -> 000525.jpg
#   Moving 000262.jpg -> 000526.jpg
#   Moving 000263.jpg -> 000527.jpg
#   Moving 000264.jpg -> 000528.jpg
#   Moving 000265.jpg -> 000529.jpg
#   Moving 000266.jpg -> 000530.jpg
#   Moving 000267.jpg -> 000531.jpg
#   Moving 000268.jpg -> 000532.jpg
#   Moving 000269.jpg -> 000533.jpg
#   Moving 000270.jpg -> 000534.jpg
#   Moving 000271.jpg -> 000535.jpg
#   Moving 000272.jpg -> 000536.jpg
#   Moving 000273.jpg -> 000537.jpg
#   Moving 000274.jpg -> 000538.jpg
#   Moving 000275.jpg -> 000539.jpg
#   Moving 000276.jpg -> 000540.jpg
#   Moving 000277.jpg -> 000541.jpg
#   Moving 000278.jpg -> 000542.jpg
#   Moving 000279.jpg -> 000543.jpg
#   Moving 000280.jpg -> 000544.jpg
#   Moving 000281.jpg -> 000545.jpg
#   Moving 000282.jpg -> 000546.jpg
#   Moving 000283.jpg -> 000547.jpg
#   Moving 000284.jpg -> 000548.jpg
#   Moving 000285.jpg -> 000549.jpg
#   Moving 000286.jpg -> 000550.jpg
#   Moving 000287.jpg -> 000551.jpg
#   Moving 000288.jpg -> 000552.jpg
#   Moving 000289.jpg -> 000553.jpg
#   Moving 000290.jpg -> 000554.jpg
#   Moving 000291.jpg -> 000555.jpg
#   Moving 000292.jpg -> 000556.jpg
#   Moving 000293.jpg -> 000557.jpg
#   Moving 000294.jpg -> 000558.jpg
#   Moving 000295.jpg -> 000559.jpg
#   Moving 000296.jpg -> 000560.jpg
#   Moving 000297.jpg -> 000561.jpg
#   Moving 000298.jpg -> 000562.jpg
#   Moving 000299.jpg -> 000563.jpg
#   Moving 000300.jpg -> 000564.jpg
#   Moving 000301.jpg -> 000565.jpg
#   Moving 000302.jpg -> 000566.jpg
#   Moving 000303.jpg -> 000567.jpg
#   Moving 000304.jpg -> 000568.jpg
#   Moving 000305.jpg -> 000569.jpg
#   Moving 000306.jpg -> 000570.jpg
#   Moving 000307.jpg -> 000571.jpg
#   Moving 000308.jpg -> 000572.jpg
#   Moving 000309.jpg -> 000573.jpg
#   Moving 000310.jpg -> 000574.jpg
#   Moving 000311.jpg -> 000575.jpg
#   Moving 000312.jpg -> 000576.jpg
#   Moving 000313.jpg -> 000577.jpg
#   Moving 000314.jpg -> 000578.jpg
#   Moving 000315.jpg -> 000579.jpg
#   Moving 000316.jpg -> 000580.jpg
#   Moving 000317.jpg -> 000581.jpg
#   Moving 000318.jpg -> 000582.jpg
#   Moving 000319.jpg -> 000583.jpg
#   Moving 000320.jpg -> 000584.jpg
#   Moving 000321.jpg -> 000585.jpg
#   Moving 000322.jpg -> 000586.jpg
#   Moving 000323.jpg -> 000587.jpg
#   Moving 000324.jpg -> 000588.jpg
#   Moving 000325.jpg -> 000589.jpg
#   Moving 000326.jpg -> 000590.jpg
#   Moving 000327.jpg -> 000591.jpg
#   Moving 000328.jpg -> 000592.jpg
#   Moving 000329.jpg -> 000593.jpg
#   Moving 000330.jpg -> 000594.jpg
#   Moving 000331.jpg -> 000595.jpg
#   Moving 000332.jpg -> 000596.jpg
#   Moving 000333.jpg -> 000597.jpg
#   Moving 000334.jpg -> 000598.jpg
#   Moving 000335.jpg -> 000599.jpg
#   Moving 000336.jpg -> 000600.jpg
#   Moving 000337.jpg -> 000601.jpg
#   Moving 000338.jpg -> 000602.jpg
#   Moving 000339.jpg -> 000603.jpg
#   Moving 000340.jpg -> 000604.jpg
#   Moving 000341.jpg -> 000605.jpg
#   Moving 000342.jpg -> 000606.jpg
#   Moving 000343.jpg -> 000607.jpg
#   Moving 000344.jpg -> 000608.jpg
#   Moving 000345.jpg -> 000609.jpg
#   Moving 000346.jpg -> 000610.jpg
#   Moving 000347.jpg -> 000611.jpg
#   Moving 000348.jpg -> 000612.jpg
#   Moving 000349.jpg -> 000613.jpg
#   Moving 000350.jpg -> 000614.jpg
#   Moving 000351.jpg -> 000615.jpg
#   Moving 000352.jpg -> 000616.jpg
#   Moving 000353.jpg -> 000617.jpg
#   Moving 000354.jpg -> 000618.jpg
#   Moving 000355.jpg -> 000619.jpg
#   Moving 000356.jpg -> 000620.jpg
#   Moving 000357.jpg -> 000621.jpg
#   Moving 000358.jpg -> 000622.jpg
#   Moving 000359.jpg -> 000623.jpg
#   Moving 000360.jpg -> 000624.jpg
#   Moving 000361.jpg -> 000625.jpg
#   Moving 000362.jpg -> 000626.jpg
#   Moving 000363.jpg -> 000627.jpg
#   Moving 000364.jpg -> 000628.jpg
#   Moving 000365.jpg -> 000629.jpg
#   Moving 000366.jpg -> 000630.jpg
#   Moving 000367.jpg -> 000631.jpg
#   Moving 000368.jpg -> 000632.jpg
#   Moving 000369.jpg -> 000633.jpg
#   Moving 000370.jpg -> 000634.jpg
#   Moving 000371.jpg -> 000635.jpg
#   Moving 000372.jpg -> 000636.jpg
#   Moving 000373.jpg -> 000637.jpg
#   Moving 000374.jpg -> 000638.jpg
#   Moving 000375.jpg -> 000639.jpg
#   Moving 000376.jpg -> 000640.jpg
#   Moving 000377.jpg -> 000641.jpg
#   Moving 000378.jpg -> 000642.jpg
#   Moving 000379.jpg -> 000643.jpg
#   Moving 000380.jpg -> 000644.jpg
#   Moving 000381.jpg -> 000645.jpg
#   Moving 000382.jpg -> 000646.jpg
#   Moving 000383.jpg -> 000647.jpg
#   Moving 000384.jpg -> 000648.jpg
#   Moving 000385.jpg -> 000649.jpg
#   Moving 000386.jpg -> 000650.jpg
#   Moving 000387.jpg -> 000651.jpg
#   Moving 000388.jpg -> 000652.jpg
#   Moving 000389.jpg -> 000653.jpg
#   Moving 000390.jpg -> 000654.jpg
#   Moving 000391.jpg -> 000655.jpg
#   Moving 000392.jpg -> 000656.jpg
#   Moving 000393.jpg -> 000657.jpg
#   Moving 000394.jpg -> 000658.jpg
#   Moving 000395.jpg -> 000659.jpg
#   Moving 000396.jpg -> 000660.jpg
#   Moving 000397.jpg -> 000661.jpg
#   Moving 000398.jpg -> 000662.jpg
#   Moving 000399.jpg -> 000663.jpg
#   Moving 000400.jpg -> 000664.jpg
#   Moving 000401.jpg -> 000665.jpg
#   Moving 000402.jpg -> 000666.jpg
#   Moving 000403.jpg -> 000667.jpg
#   Moving 000404.jpg -> 000668.jpg
#   Moving 000405.jpg -> 000669.jpg
#   Moving 000406.jpg -> 000670.jpg
#   Moving 000407.jpg -> 000671.jpg
#   Moving 000408.jpg -> 000672.jpg
#   Moving 000409.jpg -> 000673.jpg
#   Moving 000410.jpg -> 000674.jpg
#   Moving 000411.jpg -> 000675.jpg
#   Moving 000412.jpg -> 000676.jpg
#   Moving 000413.jpg -> 000677.jpg
#   Moving 000414.jpg -> 000678.jpg
#   Moving 000415.jpg -> 000679.jpg
#   Moving 000416.jpg -> 000680.jpg
#   Moving 000417.jpg -> 000681.jpg
#   Moving 000418.jpg -> 000682.jpg
#   Moving 000419.jpg -> 000683.jpg
#   Moving 000420.jpg -> 000684.jpg
#   Moving 000421.jpg -> 000685.jpg
#   Moving 000422.jpg -> 000686.jpg
#   Moving 000423.jpg -> 000687.jpg
#   Moving 000424.jpg -> 000688.jpg
#   Moving 000425.jpg -> 000689.jpg
#   Moving 000426.jpg -> 000690.jpg
#   Moving 000427.jpg -> 000691.jpg
#   Moving 000428.jpg -> 000692.jpg
#   Moving 000429.jpg -> 000693.jpg
#   Moving 000430.jpg -> 000694.jpg
#   Moving 000431.jpg -> 000695.jpg
#   Moving 000432.jpg -> 000696.jpg
#   Moving 000433.jpg -> 000697.jpg
#   Moving 000434.jpg -> 000698.jpg
#   Moving 000435.jpg -> 000699.jpg
#   Moving 000436.jpg -> 000700.jpg
#   Moving 000437.jpg -> 000701.jpg
#   Moving 000438.jpg -> 000702.jpg
#   Moving 000439.jpg -> 000703.jpg
#   Moving 000440.jpg -> 000704.jpg
#   Moving 000441.jpg -> 000705.jpg
#   Moving 000442.jpg -> 000706.jpg
#   Moving 000443.jpg -> 000707.jpg
#   Moving 000444.jpg -> 000708.jpg
#   Moving 000445.jpg -> 000709.jpg
#   Moving 000446.jpg -> 000710.jpg
#   Moving 000447.jpg -> 000711.jpg
#   Moving 000448.jpg -> 000712.jpg
#   Moving 000449.jpg -> 000713.jpg
#   Moving 000450.jpg -> 000714.jpg
#   Moving 000451.jpg -> 000715.jpg
#   Moving 000452.jpg -> 000716.jpg
#   Moving 000453.jpg -> 000717.jpg
#   Moving 000454.jpg -> 000718.jpg
#   Moving 000455.jpg -> 000719.jpg
#   Moving 000456.jpg -> 000720.jpg
#   Moving 000457.jpg -> 000721.jpg
#   Moving 000458.jpg -> 000722.jpg
#   Moving 000459.jpg -> 000723.jpg
#   Moving 000460.jpg -> 000724.jpg
#   Moving 000461.jpg -> 000725.jpg
#   Moving 000462.jpg -> 000726.jpg
#   Moving 000463.jpg -> 000727.jpg
#   Moving 000464.jpg -> 000728.jpg
#   Moving 000465.jpg -> 000729.jpg
#   Moving 000466.jpg -> 000730.jpg
#   Moving 000467.jpg -> 000731.jpg
#   Moving 000468.jpg -> 000732.jpg
#   Moving 000469.jpg -> 000733.jpg
#   Moving 000470.jpg -> 000734.jpg
#   Moving 000471.jpg -> 000735.jpg
#   Moving 000472.jpg -> 000736.jpg
#   Moving 000473.jpg -> 000737.jpg
#   Moving 000474.jpg -> 000738.jpg
#   Moving 000475.jpg -> 000739.jpg
#   Moving 000476.jpg -> 000740.jpg
#   Moving 000477.jpg -> 000741.jpg
#   Moving 000478.jpg -> 000742.jpg
#   Moving 000479.jpg -> 000743.jpg
#   Moving 000480.jpg -> 000744.jpg
#   Moving 000481.jpg -> 000745.jpg
#   Moving 000482.jpg -> 000746.jpg
#   Moving 000483.jpg -> 000747.jpg
#   Moving 000484.jpg -> 000748.jpg
#   Moving 000485.jpg -> 000749.jpg
#   Moving 000486.jpg -> 000750.jpg
#   Moving 000487.jpg -> 000751.jpg
#   Moving 000488.jpg -> 000752.jpg
#   Moving 000489.jpg -> 000753.jpg
#   Moving 000490.jpg -> 000754.jpg
#   Moving 000491.jpg -> 000755.jpg
#   Moving 000492.jpg -> 000756.jpg
#   Moving 000493.jpg -> 000757.jpg
#   Moving 000494.jpg -> 000758.jpg
#   Moving 000495.jpg -> 000759.jpg
#   Moving 000496.jpg -> 000760.jpg
#   Moving 000497.jpg -> 000761.jpg
#   Moving 000498.jpg -> 000762.jpg
#   Moving 000499.jpg -> 000763.jpg
#   Moving 000500.jpg -> 000764.jpg
#   Moving 000501.jpg -> 000765.jpg
#   Moving 000502.jpg -> 000766.jpg
#   Moving 000503.jpg -> 000767.jpg
#   Moving 000504.jpg -> 000768.jpg
#   Moving 000505.jpg -> 000769.jpg
#   Moving 000506.jpg -> 000770.jpg
#   Moving 000507.jpg -> 000771.jpg
#   Moving 000508.jpg -> 000772.jpg
#   Moving 000509.jpg -> 000773.jpg
#   Moving 000510.jpg -> 000774.jpg
#   Moving 000511.jpg -> 000775.jpg
#   Moving 000512.jpg -> 000776.jpg
#   Moving 000513.jpg -> 000777.jpg
#   Moving 000514.jpg -> 000778.jpg
#   Moving 000515.jpg -> 000779.jpg
#   Moving 000516.jpg -> 000780.jpg
#   Moving 000517.jpg -> 000781.jpg
#   Moving 000518.jpg -> 000782.jpg
#   Moving 000519.jpg -> 000783.jpg
#   Moving 000520.jpg -> 000784.jpg
#   Moving 000521.jpg -> 000785.jpg
#   Moving 000522.jpg -> 000786.jpg
#   Moving 000523.jpg -> 000787.jpg
#   Moving 000524.jpg -> 000788.jpg
#   Moving 000525.jpg -> 000789.jpg
#   Moving 000526.jpg -> 000790.jpg
#   Moving 000527.jpg -> 000791.jpg
#   Moving 000528.jpg -> 000792.jpg
#   Moving 000529.jpg -> 000793.jpg
#   Moving 000530.jpg -> 000794.jpg
#   Moving 000531.jpg -> 000795.jpg
#   Moving 000532.jpg -> 000796.jpg
#   Moving 000533.jpg -> 000797.jpg
#   Moving 000534.jpg -> 000798.jpg
#   Moving 000535.jpg -> 000799.jpg
#   Moving 000536.jpg -> 000800.jpg
#   Moving 000537.jpg -> 000801.jpg
#   Moving 000538.jpg -> 000802.jpg
#   Moving 000539.jpg -> 000803.jpg
#   Moving 000540.jpg -> 000804.jpg
#   Moving 000541.jpg -> 000805.jpg
#   Moving 000542.jpg -> 000806.jpg
#   Moving 000543.jpg -> 000807.jpg
#   Moving 000544.jpg -> 000808.jpg
#   Moving 000545.jpg -> 000809.jpg
#   Moving 000546.jpg -> 000810.jpg
#   Moving 000547.jpg -> 000811.jpg
#   Moving 000548.jpg -> 000812.jpg
#   Moving 000549.jpg -> 000813.jpg
#   Moving 000550.jpg -> 000814.jpg
#   Moving 000551.jpg -> 000815.jpg
#   Moving 000552.jpg -> 000816.jpg
#   Moving 000553.jpg -> 000817.jpg
#   Moving 000554.jpg -> 000818.jpg
#   Moving 000555.jpg -> 000819.jpg
#   Moving 000556.jpg -> 000820.jpg
#   Moving 000557.jpg -> 000821.jpg
#   Moving 000558.jpg -> 000822.jpg
#   Moving 000559.jpg -> 000823.jpg
#   Moving 000560.jpg -> 000824.jpg
#   Moving 000561.jpg -> 000825.jpg
#   Moving 000562.jpg -> 000826.jpg
#   Moving 000563.jpg -> 000827.jpg
#   Moving 000564.jpg -> 000828.jpg
#   Moving 000565.jpg -> 000829.jpg
#   Moving 000566.jpg -> 000830.jpg
#   Moving 000567.jpg -> 000831.jpg
#   Moving 000568.jpg -> 000832.jpg
#   Moving 000569.jpg -> 000833.jpg
#   Moving 000570.jpg -> 000834.jpg
#   Moving 000571.jpg -> 000835.jpg
#   Moving 000572.jpg -> 000836.jpg
#   Moving 000573.jpg -> 000837.jpg
#   Moving 000574.jpg -> 000838.jpg
#   Moving 000575.jpg -> 000839.jpg
#   Moving 000576.jpg -> 000840.jpg
#   Moving 000577.jpg -> 000841.jpg
#   Moving 000578.jpg -> 000842.jpg
#   Moving 000579.jpg -> 000843.jpg
#   Moving 000580.jpg -> 000844.jpg
#   Moving 000581.jpg -> 000845.jpg
#   Moving 000582.jpg -> 000846.jpg
#   Moving 000583.jpg -> 000847.jpg
#   Moving 000584.jpg -> 000848.jpg
#   Moving 000585.jpg -> 000849.jpg
#   Moving 000586.jpg -> 000850.jpg
#   Moving 000587.jpg -> 000851.jpg
#   Moving 000588.jpg -> 000852.jpg
#   Moving 000589.jpg -> 000853.jpg
#   Moving 000590.jpg -> 000854.jpg
#   Moving 000591.jpg -> 000855.jpg
#   Moving 000592.jpg -> 000856.jpg
#   Moving 000593.jpg -> 000857.jpg
#   Moving 000594.jpg -> 000858.jpg
#   Moving 000595.jpg -> 000859.jpg
#   Moving 000596.jpg -> 000860.jpg
#   Moving 000597.jpg -> 000861.jpg
#   Moving 000598.jpg -> 000862.jpg
#   Moving 000599.jpg -> 000863.jpg
#   Moving 000600.jpg -> 000864.jpg
#   Moving 000601.jpg -> 000865.jpg
#   Moving 000602.jpg -> 000866.jpg
#   Moving 000603.jpg -> 000867.jpg
#   Moving 000604.jpg -> 000868.jpg
#   Moving 000605.jpg -> 000869.jpg
#   Moving 000606.jpg -> 000870.jpg
#   Moving 000607.jpg -> 000871.jpg
#   Moving 000608.jpg -> 000872.jpg
#   Moving 000609.jpg -> 000873.jpg
#   Moving 000610.jpg -> 000874.jpg
#   Moving 000611.jpg -> 000875.jpg
#   Moving 000612.jpg -> 000876.jpg
#   Moving 000613.jpg -> 000877.jpg
#   Moving 000614.jpg -> 000878.jpg
#   Moving 000615.jpg -> 000879.jpg
#   Moving 000616.jpg -> 000880.jpg
#   Moving 000617.jpg -> 000881.jpg
#   Moving 000618.jpg -> 000882.jpg
#   Moving 000619.jpg -> 000883.jpg
#   Moving 000620.jpg -> 000884.jpg
#   Moving 000621.jpg -> 000885.jpg
#   Moving 000622.jpg -> 000886.jpg
#   Moving 000623.jpg -> 000887.jpg
#   Moving 000624.jpg -> 000888.jpg
#   Moving 000625.jpg -> 000889.jpg
#   Moving 000626.jpg -> 000890.jpg
#   Moving 000627.jpg -> 000891.jpg
#   Moving 000628.jpg -> 000892.jpg
#   Moving 000629.jpg -> 000893.jpg
#   Moving 000630.jpg -> 000894.jpg
#   Moving 000631.jpg -> 000895.jpg
#   Moving 000632.jpg -> 000896.jpg
#   Moving 000633.jpg -> 000897.jpg
#   Moving 000634.jpg -> 000898.jpg
#   Moving 000635.jpg -> 000899.jpg
#   Moving 000636.jpg -> 000900.jpg
#   Moving 000637.jpg -> 000901.jpg
#   Moving 000638.jpg -> 000902.jpg
#   Moving 000639.jpg -> 000903.jpg
#   Moving 000640.jpg -> 000904.jpg
#   Moving 000641.jpg -> 000905.jpg
#   Moving 000642.jpg -> 000906.jpg
#   Moving 000643.jpg -> 000907.jpg
#   Moving 000644.jpg -> 000908.jpg
#   Moving 000645.jpg -> 000909.jpg
#   Moving 000646.jpg -> 000910.jpg
#   Moving 000647.jpg -> 000911.jpg
#   Moving 000648.jpg -> 000912.jpg
#   Moving 000649.jpg -> 000913.jpg
#   Moving 000650.jpg -> 000914.jpg
#   Moving 000651.jpg -> 000915.jpg
#   Moving 000652.jpg -> 000916.jpg
#   Moving 000653.jpg -> 000917.jpg
#   Moving 000654.jpg -> 000918.jpg
#   Moving 000655.jpg -> 000919.jpg
#   Moving 000656.jpg -> 000920.jpg
#   Moving 000657.jpg -> 000921.jpg
#   Moving 000658.jpg -> 000922.jpg
#   Moving 000659.jpg -> 000923.jpg
#   Moving 000660.jpg -> 000924.jpg
#   Moving 000661.jpg -> 000925.jpg
#   Moving 000662.jpg -> 000926.jpg
#   Moving 000663.jpg -> 000927.jpg
#   Moving 000664.jpg -> 000928.jpg
#   Moving 000665.jpg -> 000929.jpg
#   Moving 000666.jpg -> 000930.jpg
#   Moving 000667.jpg -> 000931.jpg
#   Moving 000668.jpg -> 000932.jpg
#   Moving 000669.jpg -> 000933.jpg
#   Moving 000670.jpg -> 000934.jpg
#   Moving 000671.jpg -> 000935.jpg
#   Moving 000672.jpg -> 000936.jpg
#   Moving 000673.jpg -> 000937.jpg
#   Moving 000674.jpg -> 000938.jpg
#   Moving 000675.jpg -> 000939.jpg
#   Moving 000676.jpg -> 000940.jpg
#   Moving 000677.jpg -> 000941.jpg
#   Moving 000678.jpg -> 000942.jpg
#   Moving 000679.jpg -> 000943.jpg
#   Moving 000680.jpg -> 000944.jpg
#   Moving 000681.jpg -> 000945.jpg
#   Moving 000682.jpg -> 000946.jpg
#   Moving 000683.jpg -> 000947.jpg
#   Moving 000684.jpg -> 000948.jpg
#   Moving 000685.jpg -> 000949.jpg
#   Moving 000686.jpg -> 000950.jpg
#   Moving 000687.jpg -> 000951.jpg
#   Moving 000688.jpg -> 000952.jpg
#   Moving 000689.jpg -> 000953.jpg
#   Moving 000690.jpg -> 000954.jpg
#   Moving 000691.jpg -> 000955.jpg
#   Moving 000692.jpg -> 000956.jpg
# Cleaning up empty source folder: /fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset/train/images/abeq2
# Cleaning up empty source folder: /fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset/train/labels/abeq2
#
# Processing 'valid' set...
# 'images' contains 31 images. New files will start from index 32.
#   Moving 000001.jpg -> 000032.jpg
#   Moving 000002.jpg -> 000033.jpg
#   Moving 000003.jpg -> 000034.jpg
#   Moving 000004.jpg -> 000035.jpg
#   Moving 000005.jpg -> 000036.jpg
#   Moving 000006.jpg -> 000037.jpg
#   Moving 000007.jpg -> 000038.jpg
#   Moving 000008.jpg -> 000039.jpg
#   Moving 000009.jpg -> 000040.jpg
#   Moving 000010.jpg -> 000041.jpg
#   Moving 000011.jpg -> 000042.jpg
#   Moving 000012.jpg -> 000043.jpg
#   Moving 000013.jpg -> 000044.jpg
#   Moving 000014.jpg -> 000045.jpg
#   Moving 000015.jpg -> 000046.jpg
#   Moving 000016.jpg -> 000047.jpg
#   Moving 000017.jpg -> 000048.jpg
#   Moving 000018.jpg -> 000049.jpg
#   Moving 000019.jpg -> 000050.jpg
#   Moving 000020.jpg -> 000051.jpg
#   Moving 000021.jpg -> 000052.jpg
#   Moving 000022.jpg -> 000053.jpg
#   Moving 000023.jpg -> 000054.jpg
#   Moving 000024.jpg -> 000055.jpg
#   Moving 000025.jpg -> 000056.jpg
#   Moving 000026.jpg -> 000057.jpg
#   Moving 000027.jpg -> 000058.jpg
#   Moving 000028.jpg -> 000059.jpg
#   Moving 000029.jpg -> 000060.jpg
#   Moving 000030.jpg -> 000061.jpg
#   Moving 000031.jpg -> 000062.jpg
#   Moving 000032.jpg -> 000063.jpg
#   Moving 000033.jpg -> 000064.jpg
#   Moving 000034.jpg -> 000065.jpg
#   Moving 000035.jpg -> 000066.jpg
#   Moving 000036.jpg -> 000067.jpg
#   Moving 000037.jpg -> 000068.jpg
#   Moving 000038.jpg -> 000069.jpg
#   Moving 000039.jpg -> 000070.jpg
#   Moving 000040.jpg -> 000071.jpg
#   Moving 000041.jpg -> 000072.jpg
#   Moving 000042.jpg -> 000073.jpg
#   Moving 000043.jpg -> 000074.jpg
#   Moving 000044.jpg -> 000075.jpg
#   Moving 000045.jpg -> 000076.jpg
#   Moving 000046.jpg -> 000077.jpg
#   Moving 000047.jpg -> 000078.jpg
#   Moving 000048.jpg -> 000079.jpg
#   Moving 000049.jpg -> 000080.jpg
#   Moving 000050.jpg -> 000081.jpg
#   Moving 000051.jpg -> 000082.jpg
#   Moving 000052.jpg -> 000083.jpg
#   Moving 000053.jpg -> 000084.jpg
#   Moving 000054.jpg -> 000085.jpg
#   Moving 000055.jpg -> 000086.jpg
#   Moving 000056.jpg -> 000087.jpg
#   Moving 000057.jpg -> 000088.jpg
#   Moving 000058.jpg -> 000089.jpg
#   Moving 000059.jpg -> 000090.jpg
#   Moving 000060.jpg -> 000091.jpg
#   Moving 000061.jpg -> 000092.jpg
#   Moving 000062.jpg -> 000093.jpg
#   Moving 000063.jpg -> 000094.jpg
#   Moving 000064.jpg -> 000095.jpg
#   Moving 000065.jpg -> 000096.jpg
#   Moving 000066.jpg -> 000097.jpg
#   Moving 000067.jpg -> 000098.jpg
#   Moving 000068.jpg -> 000099.jpg
#   Moving 000069.jpg -> 000100.jpg
#   Moving 000070.jpg -> 000101.jpg
#   Moving 000071.jpg -> 000102.jpg
#   Moving 000072.jpg -> 000103.jpg
# Cleaning up empty source folder: /fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset/valid/images/abeq2
# Cleaning up empty source folder: /fs/nexus-scratch/hwahed/dlcDatasetMaker/dataset/valid/labels/abeq2
#
# --------------------------------------------------
# Merge process completed successfully.
